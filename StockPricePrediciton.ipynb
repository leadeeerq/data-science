# %% [markdown]
# <a href="https://colab.research.google.com/github/leadeeerq/data-science/blob/main/StockPricePrediciton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Stock price prediciton

# %%
# !pip install Quandl

# %%
import pandas as pd
import quandl, math, datetime
import numpy as np
import pickle
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from matplotlib import style

style.use('ggplot')

# %% [markdown]
# ##Import df from Quandl

# %%
data = quandl.get('WIKI/GOOGL')
data.to_csv('googl.csv')
df = pd.read_csv('googl.csv', index_col='Date', parse_dates=True)

# %%
df.head()
# Out:
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19  100.01  104.06   95.96  100.335  44659000.0          0.0
# 2004-08-20  101.01  109.08  100.50  108.310  22834300.0          0.0
# 2004-08-23  110.76  113.48  109.05  109.400  18256100.0          0.0
# 2004-08-24  111.24  111.60  103.57  104.870  15247300.0          0.0
# 2004-08-25  104.76  108.00  103.88  106.000   9188600.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2004-08-19          1.0  50.159839  52.191109  48.128568   50.322842
# 2004-08-20          1.0  50.661387  54.708881  50.405597   54.322689
# 2004-08-23          1.0  55.551482  56.915693  54.693835   54.869377
# 2004-08-24          1.0  55.792225  55.972783  51.945350   52.597363
# 2004-08-25          1.0  52.542193  54.167209  52.100830   53.164113
#
#             Adj. Volume
# Date
# 2004-08-19   44659000.0
# 2004-08-20   22834300.0
# 2004-08-23   18256100.0
# 2004-08-24   15247300.0
# 2004-08-25    9188600.0

# %%
df = df[['Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close', 'Adj. Volume']]

# %%
df['pct_HL'] = (df['Adj. High'] - df['Adj. Low'])/df['Adj. Low'] * 100.0 #daily volatility/zmienność w ciągu dnia
# df['pct_HL'] = (df['Adj. High'] - df['Adj. Close'])/df['Adj. Close'] * 100.0
df['pct_change'] = (df['Adj. Close'] - df['Adj. Open'])/df['Adj. Open'] * 100.0

# %%
df = df[['Adj. Close', 'pct_HL', 'pct_change', 'Adj. Volume']]
df.head()
# Out:
#             Adj. Close    pct_HL  pct_change  Adj. Volume
# Date
# 2004-08-19   50.322842  8.441017    0.324968   44659000.0
# 2004-08-20   54.322689  8.537313    7.227007   22834300.0
# 2004-08-23   54.869377  4.062357   -1.227880   18256100.0
# 2004-08-24   52.597363  7.753210   -5.726357   15247300.0
# 2004-08-25   53.164113  3.966115    1.183658    9188600.0

# %%
forecast_col = 'Adj. Close'

# %% [markdown]
# ###Filling nans with outliers (-99999)

# %%
df.fillna(-99999, inplace = True)

# %% [markdown]
# ###Forecast_out - predicting 0.1 of quantity of data fed

# %%
forecast_out = int(math.ceil(0.1 * len(df))) #Wykorzystanie x dni poprzedzających do predykcji dzisiejszego dnia
forecast_out
# Out:
# 343

# %%
df['label'] = df[forecast_col].shift(-forecast_out) #Przesunięcie wyników Adj.Close o x w górę, aby mieć informację o cenie akcji po x dniach; usunięcie x pierwszych wierszy

# %%
df.head()
# Out:
#             Adj. Close    pct_HL  pct_change  Adj. Volume       label
# Date
# 2004-08-19   50.322842  8.441017    0.324968   44659000.0  214.005615
# 2004-08-20   54.322689  8.537313    7.227007   22834300.0  210.725489
# 2004-08-23   54.869377  4.062357   -1.227880   18256100.0  208.072299
# 2004-08-24   52.597363  7.753210   -5.726357   15247300.0  218.288837
# 2004-08-25   53.164113  3.966115    1.183658    9188600.0  223.309335

# %% [markdown]
# ##Train, test split

# %%
X = np.array(df.drop(['label'], 1))
X = preprocessing.scale(X)
X_lately = X[-forecast_out:]
X = X[:-forecast_out]

df.dropna(inplace = True)

y = np.array(df['label'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
print(len(X), len(y))
# Out:
# 3081 3081

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# ##Classifier

# %% [markdown]
# ###Linear Regression

# %%
clf = LinearRegression(n_jobs = -1)
clf.fit(X_train, y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
accuracy = clf.score(X_test, y_test)
accuracy
# Out:
# 0.8786021189071224

# %% [markdown]
# ###SVR

# %%
# clf = svm.SVR(kernel = 'poly')
# clf.fit(X_train, y_train)
# accuracy = clf.score(X_test, y_test)
# accuracy

# %% [markdown]
# ##Saving the classifier using Pickle

# %%
with open('linearregression.pickle', 'wb') as f:
  pickle.dump(clf, f)

# %%
pickle_in = open('linearregression.pickle', 'rb')
clf = pickle.load(pickle_in)

# %% [markdown]
# ##Predicition

# %%
#        1204.31607407, 1214.17465766, 1210.98941235, 1213.1244276 ,
#        1206.48844326, 1232.26043161, 1242.43844882, 1237.60979175,
#        1236.5397065 , 1259.04720616, 1254.3345548 , 1255.80275842,
#        1259.47750453, 1260.34078613, 1263.65019784, 1249.37877696,
#        1251.35266561, 1237.24743975, 1234.43016024, 1240.69769498,
#        1239.98759352, 1299.44176996, 1291.22071016, 1290.44690593,
#        1300.87470502, 1304.08344244, 1310.27776412, 1300.79035874,
#        1312.02886246, 1308.36625639, 1299.51926651, 1298.16383949,
#        1300.52366935, 1291.94464486, 1309.01107586, 1295.93073615,
#        1288.32937907, 1309.92113111, 1310.84588601, 1316.33597372,
#        1339.65336017, 1333.45578711, 1302.92887321, 1293.27003842,
#        1283.61299939, 1268.66336734, 1284.546925  , 1295.20549922,
#        1303.799463  , 1308.27585678, 1312.53320414, 1311.13900043,
#        1309.91880796, 1319.6249364 , 1336.55613354, 1354.88336226,
#        1347.02057269, 1339.28529474, 1333.90499297, 1329.37033742,
#        1328.97486193, 1321.79876268, 1317.47865385, 1310.71462257,
#        1343.6775779 , 1365.96850332, 1365.04877407, 1383.5266383 ,
#        1387.44144534, 1386.27670382, 1382.39194896, 1384.31755741,
#        1413.74340376, 1413.97790097, 1421.28574957, 1417.74387561,
#        1424.21532106, 1456.17061699, 1463.90392019, 1462.47073403,
#        1472.75145195, 1481.97557084, 1478.34155621, 1466.58950446,
#        1473.17107035, 1472.88992062, 1394.44529027, 1356.21767075,
#        1373.66957148, 1326.79084964, 1281.58404509, 1322.74437847,
#        1318.42685687, 1315.90389824, 1344.09335118, 1368.0712093 ,
#        1367.53811799, 1382.65955447, 1395.96917442, 1387.970713  ,
#        1410.20386907, 1426.05068054, 1400.55608257, 1381.94213455,
#        1352.75647615, 1363.52301634, 1373.46299345, 1372.20301813,
#        1396.61184037, 1408.10673504, 1452.26979879, 1454.89096874,
#        1436.11200603, 1433.27297498, 1440.69259528, 1419.47936089,
#        1379.68665708, 1370.66328549, 1368.20645729, 1324.35136328,
#        1297.29283385, 1333.73501189, 1288.34069354])

# %%
for i in forecast_set:
  next_date = datetime.datetime.fromtimestamp(next_unix)
  next_unix += one_day
  df.loc[next_date] = [np.nan for _ in range(len(df.columns)-1)] + [i]

# %%
df[-40:-30]
# Out:
#             Adj. Close  pct_HL  pct_change  Adj. Volume  label     Forecast
# Date
# 2017-09-10         NaN     NaN         NaN          NaN    NaN  1466.589504
# 2017-09-11         NaN     NaN         NaN          NaN    NaN  1473.171070
# 2017-09-12         NaN     NaN         NaN          NaN    NaN  1472.889921
# 2017-09-13         NaN     NaN         NaN          NaN    NaN  1394.445290
# 2017-09-14         NaN     NaN         NaN          NaN    NaN  1356.217671
# 2017-09-15         NaN     NaN         NaN          NaN    NaN  1373.669571
# 2017-09-16         NaN     NaN         NaN          NaN    NaN  1326.790850
# 2017-09-17         NaN     NaN         NaN          NaN    NaN  1281.584045
# 2017-09-18         NaN     NaN         NaN          NaN    NaN  1322.744378
# 2017-09-19         NaN     NaN         NaN          NaN    NaN  1318.426857

# %%
df['Adj. Close'].plot()
df['Forecast'].plot()
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.legend(loc = 4)
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')
